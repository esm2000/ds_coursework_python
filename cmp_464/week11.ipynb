# %% [markdown]
# # Chapter 7 Data Cleaning and Preparation
#
# During the course of doing data analysis and modeling, a significant amount of time is spent on data preparation: loading, cleaning, transforming, and rearranging. Such tasks are often reported to take up 80% or more of an analyst's time. In this chapter, let's study tools for missing data, duplicate data, string manipulation, and some other analytical data transformations.

# %% [markdown]
# ## I. An Example of Handling Missing Values
#
# The [Pima Indians Diabetes Dataset](https://www.kaggle.com/uciml/pima-indians-diabetes-database) involves predicting the onset of diabetes within 5 years in Pima Indians given medical details.
#
# It is a binary (2-class) classification problem. The number of observations for each class is not balanced. There are 768 observations with 8 input variables and 1 output variable. The variable names are as follows:
#
# 0. Number of times pregnant.
# 1. Plasma glucose concentration a 2 hours in an oral glucose tolerance test.
# 2. Diastolic blood pressure (mm Hg).
# 3. Triceps skinfold thickness (mm).
# 4. 2-Hour serum insulin (mu U/ml).
# 5. Body mass index (weight in kg/(height in m)^2).
# 6. Diabetes pedigree function.
# 7. Age (years).
# 8. Class variable (0 or 1).

# %%
# https://machinelearningmastery.com/handle-missing-data-python/
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('Data/diabetes/diabetes.csv', delimiter=',')
data.head(3)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %% [markdown]
# In the following columns, a value of zero indicates a missing value:
#
# - Plasma glucose concentration
# - Diastolic blood pressure
# - Triceps skinfold thickness
# - 2-Hour serum insulin
# - Body mass index

# %%
# Find how many missing values exist in each column
zero_filter = (data["Glucose"] == 0) | (data["BloodPressure"] == 0) | (data["SkinThickness"] == 0) | (data["Insulin"] == 0) | (data["BMI"] == 0)
data2 = data[zero_filter]

columns = ["Glucose", "BloodPressure", "SkinThickness", "Insulin", "BMI"]

for column in columns:
    temp_filter = data[column] == 0
    print(column + ": " + str(len(data[temp_filter])))
# Out:
# Glucose: 5
# BloodPressure: 35
# SkinThickness: 227
# Insulin: 374
# BMI: 11

# %% [markdown]
# We can see that Glucose, BloodPressure, and BMI have just a few zero values, while SkinThickness and Insulin show nearly half of the rows missing.

# %%
# We should mark missing values with np.nan, so that these values can be
# correctly ignored from operations such as sum, count, min, etc.

for column in columns:
    for i in np.arange(0, len(data[column])):
        if data[column][i] == 0:
            data[column][i] = np.nan
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\Anaconda3\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
# Use isnull() to find the number of missing values
data.isnull().sum()
# Out:
# Pregnancies                   0
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                       0
# dtype: int64

# %% [markdown]
# ## Approach 1: Remove Rows/Columns with Missing values
#
# The simpliest strategy for handling missing data is to remove rows/columns that contain a missing value.

# %%
# Pandas provides the dropna() function that can be used to drop either columns or rows \
# with missing data.
data3 = data

data3 = data3.dropna()
data3 = data3.reset_index(drop = True)

data3.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            1     89.0           66.0           23.0     94.0  28.1
# 1            0    137.0           40.0           35.0    168.0  43.1
# 2            3     78.0           50.0           32.0     88.0  31.0
# 3            2    197.0           70.0           45.0    543.0  30.5
# 4            1    189.0           60.0           23.0    846.0  30.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.167   21        0
# 1                     2.288   33        1
# 2                     0.248   26        1
# 3                     0.158   53        1
# 4                     0.398   59        1

# %%
data3.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# Removing rows with missing values may significantly reduce the number of rows, and thus hurt the quality of dataset. This approach is only recommended if the number of missing values is small.

# %%
len(data)
# Out:
# 768

# %%
len(data3)
# Out:
# 392

# %% [markdown]
# ## Approach 2: Replace Missing Values with Mean or Median
#
# The mean and median represent the "average" value of the column, and thus can be a reasonable guess on the missing values.

# %%
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Pandas provides fillna() function for replacing missing values with a 
# specific value.
data4 = data
for column in columns:
    data4[column] = data4[column].fillna(data4[column].mean())

# %%
data4.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
data = pd.read_csv('Data/diabetes/diabetes.csv', delimiter=',')
data.head(3)
for column in columns:
    for i in np.arange(0, len(data[column])):
        if data[column][i] == 0:
            data[column][i] = np.nan
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
data.isnull().sum()
# Out:
# Pregnancies                   0
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                       0
# dtype: int64

# %% [markdown]
# **Discussion:**
# 1. When is median value preferred over the mean value?
#
#     __Median value is preferred over the mean value in prescence of a significant amount of outliers.__
#
#
#
# 2. What are the limitations of mean/median imputation?
#
#     __The limitations of the mean/median imputation is that you're making an assumption that the mean/median of the missing values are the mean/median of the entire dataset and variance is not preserved.__

# %% [markdown]
# ## Approach 3: Hot Deck Imputation
# **Hot deck imputation** is a method for handling missing data by replacing them with an random observed value. This imputation method preserves the variance of the dataset.

# %%
# Write a function that implements hot deck imputation, and then
# use apply() to apply this function to the data frame

data5 = data.copy()

for col in data5.columns:
    for i in data5.index:
        if pd.isnull(data.loc[i, col]):
            data5.loc[i, col] = np.random.choice(data5[col].dropna())

data5
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6    148.0           72.0           35.0     36.0  33.6
# 1              1     85.0           66.0           29.0    207.0  26.6
# 2              8    183.0           64.0           33.0    215.0  23.3
# 3              1     89.0           66.0           23.0     94.0  28.1
# 4              0    137.0           40.0           35.0    168.0  43.1
# 5              5    116.0           74.0           37.0    231.0  25.6
# 6              3     78.0           50.0           32.0     88.0  31.0
# 7             10    115.0           66.0           20.0     94.0  35.3
# 8              2    197.0           70.0           45.0    543.0  30.5
# 9              8    125.0           96.0           29.0    325.0  27.4
# 10             4    110.0           92.0           47.0    120.0  37.6
# 11            10    168.0           74.0           49.0    122.0  38.0
# 12            10    139.0           80.0           46.0    200.0  27.1
# 13             1    189.0           60.0           23.0    846.0  30.1
# 14             5    166.0           72.0           19.0    175.0  25.8
# 15             7    100.0           74.0           41.0    155.0  30.0
# 16             0    118.0           84.0           47.0    230.0  45.8
# 17             7    107.0           74.0           33.0    129.0  29.6
# 18             1    103.0           30.0           38.0     83.0  43.3
# 19             1    115.0           70.0           30.0     96.0  34.6
# 20             3    126.0           88.0           41.0    235.0  39.3
# 21             8     99.0           84.0           20.0    158.0  35.4
# 22             7    196.0           90.0           25.0     64.0  39.8
# 23             9    119.0           80.0           35.0     36.0  29.0
# 24            11    143.0           94.0           33.0    146.0  36.6
# 25            10    125.0           70.0           26.0    115.0  31.1
# 26             7    147.0           76.0           16.0    122.0  39.4
# 27             1     97.0           66.0           15.0    140.0  23.2
# 28            13    145.0           82.0           19.0    110.0  22.2
# 29             5    117.0           92.0           42.0    245.0  34.1
# ..           ...      ...            ...            ...      ...   ...
# 738            2     99.0           60.0           17.0    160.0  36.6
# 739            1    102.0           74.0           36.0     64.0  39.5
# 740           11    120.0           80.0           37.0    150.0  42.3
# 741            3    102.0           44.0           20.0     94.0  30.8
# 742            1    109.0           58.0           18.0    116.0  28.5
# 743            9    140.0           94.0           18.0     49.0  32.7
# 744           13    153.0           88.0           37.0    140.0  40.6
# 745           12    100.0           84.0           33.0    105.0  30.0
# 746            1    147.0           94.0           41.0     82.0  49.3
# 747            1     81.0           74.0           41.0     57.0  46.3
# 748            3    187.0           70.0           22.0    200.0  36.4
# 749            6    162.0           62.0           35.0     83.0  24.3
# 750            4    136.0           70.0           27.0     63.0  31.2
# 751            1    121.0           78.0           39.0     74.0  39.0
# 752            3    108.0           62.0           24.0    300.0  26.0
# 753            0    181.0           88.0           44.0    510.0  43.3
# 754            8    154.0           78.0           32.0    190.0  32.4
# 755            1    128.0           88.0           39.0    110.0  36.5
# 756            7    137.0           90.0           41.0    168.0  32.0
# 757            0    123.0           72.0           24.0    274.0  36.3
# 758            1    106.0           76.0           32.0    115.0  37.5
# 759            6    190.0           92.0           11.0    326.0  35.5
# 760            2     88.0           58.0           26.0     16.0  28.4
# 761            9    170.0           74.0           31.0    105.0  44.0
# 762            9     89.0           62.0           42.0    190.0  22.5
# 763           10    101.0           76.0           48.0    180.0  32.9
# 764            2    122.0           70.0           27.0     58.0  36.8
# 765            5    121.0           72.0           23.0    112.0  26.2
# 766            1    126.0           60.0           37.0    115.0  30.1
# 767            1     93.0           70.0           31.0     94.0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# 5                       0.201   30        0
# 6                       0.248   26        1
# 7                       0.134   29        0
# 8                       0.158   53        1
# 9                       0.232   54        1
# 10                      0.191   30        0
# 11                      0.537   34        1
# 12                      1.441   57        0
# 13                      0.398   59        1
# 14                      0.587   51        1
# 15                      0.484   32        1
# 16                      0.551   31        1
# 17                      0.254   31        1
# 18                      0.183   33        0
# 19                      0.529   32        1
# 20                      0.704   27        0
# 21                      0.388   50        0
# 22                      0.451   41        1
# 23                      0.263   29        1
# 24                      0.254   51        1
# 25                      0.205   41        1
# 26                      0.257   43        1
# 27                      0.487   22        0
# 28                      0.245   57        0
# 29                      0.337   38        0
# ..                        ...  ...      ...
# 738                     0.453   21        0
# 739                     0.293   42        1
# 740                     0.785   48        1
# 741                     0.400   26        0
# 742                     0.219   22        0
# 743                     0.734   45        1
# 744                     1.174   39        0
# 745                     0.488   46        0
# 746                     0.358   27        1
# 747                     1.096   32        0
# 748                     0.408   36        1
# 749                     0.178   50        1
# 750                     1.182   22        1
# 751                     0.261   28        0
# 752                     0.223   25        0
# 753                     0.222   26        1
# 754                     0.443   45        1
# 755                     1.057   37        1
# 756                     0.391   39        0
# 757                     0.258   52        1
# 758                     0.197   26        0
# 759                     0.278   66        1
# 760                     0.766   22        0
# 761                     0.403   43        1
# 762                     0.142   33        0
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
# Compare the standard deviation of imputed dataset with the original.
data.std()
# Out:
# Pregnancies                   3.369578
# Glucose                      30.535641
# BloodPressure                12.382158
# SkinThickness                10.476982
# Insulin                     118.775855
# BMI                           6.924988
# DiabetesPedigreeFunction      0.331329
# Age                          11.760232
# Outcome                       0.476951
# dtype: float64

# %%
data5.std()
# Out:
# Pregnancies                   3.369578
# Glucose                      30.577145
# BloodPressure                12.333788
# SkinThickness                10.727015
# Insulin                     113.769802
# BMI                           6.903038
# DiabetesPedigreeFunction      0.331329
# Age                          11.760232
# Outcome                       0.476951
# dtype: float64

# %% [markdown]
# **Advance Usage:**
#
# Approach 2 and 3 can be made more specific on which group each instance belongs to.

# %%
# Replace the missing Glucose values using the average value from people
# of the same age.
data6 = data.copy()

glucose_null_filter = pd.isnull(data6["Glucose"])
data6[glucose_null_filter]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 75             1      NaN           48.0           20.0      NaN  24.7
# 182            1      NaN           74.0           20.0     23.0  27.7
# 342            1      NaN           68.0           35.0      NaN  32.0
# 349            5      NaN           80.0           32.0      NaN  41.0
# 502            6      NaN           68.0           41.0      NaN  39.0
#
#      DiabetesPedigreeFunction  Age  Outcome
# 75                      0.140   22        0
# 182                     0.299   21        0
# 342                     0.389   22        0
# 349                     0.346   37        1
# 502                     0.727   41        1

# %%
for i in np.arange(0, len(data6["Glucose"])):
    if(pd.isnull(data6.loc[i, "Glucose"])):
        age_filter = data6["Age"] == data6.loc[i, "Age"]
        mean = data6[age_filter]["Glucose"].mean()
        
        data6.loc[i, "Glucose"] = mean

# %%
# Out:
# Empty DataFrame
# Columns: [Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome]
# Index: []

# %%
# Replace the missing BloodPressure value using a random value from people 
# of the same age.

for i in np.arange(0, len(data6["BloodPressure"])):
    if(pd.isnull(data6.loc[i, "BloodPressure"])):
        age_filter = data6["Age"] == data6.loc[i, "Age"]
        mean = data6[age_filter]["BloodPressure"].mean()
        
        data6.loc[i, "BloodPressure"] = mean

# %% [markdown]
# ## Approach 4: Add missing value indicator
#
# Sometimes the values are **not missing at random**, meaning that one cannot simply predict the missing values using existing values. If this is likely the case, then a safe approach is to add an indicator feature of whether the corresponding value is missing.

# %%
data7 = data.copy()

data7["isGlucoseMissing"] = data7["Glucose"].isnull()

# %%
data7.sample(15)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 421            2     94.0           68.0           18.0     76.0  26.0
# 113            4     76.0           62.0            NaN      NaN  34.0
# 397            0    131.0           66.0           40.0      NaN  34.3
# 155            7    152.0           88.0           44.0      NaN  50.0
# 130            4    173.0           70.0           14.0    168.0  29.7
# 225            1     87.0           78.0           27.0     32.0  34.6
# 368            3     81.0           86.0           16.0     66.0  27.5
# 144            4    154.0           62.0           31.0    284.0  32.8
# 512            9     91.0           68.0            NaN      NaN  24.2
# 248            9    124.0           70.0           33.0    402.0  35.4
# 376            0     98.0           82.0           15.0     84.0  25.2
# 288            4     96.0           56.0           17.0     49.0  20.8
# 416            1     97.0           68.0           21.0      NaN  27.2
# 590           11    111.0           84.0           40.0      NaN  46.8
# 630            7    114.0           64.0            NaN      NaN  27.4
#
#      DiabetesPedigreeFunction  Age  Outcome  isGlucoseMissing
# 421                     0.561   21        0             False
# 113                     0.391   25        0             False
# 397                     0.196   22        1             False
# 155                     0.337   36        1             False
# 130                     0.361   33        1             False
# 225                     0.101   22        0             False
# 368                     0.306   22        0             False
# 144                     0.237   23        0             False
# 512                     0.200   58        0             False
# 248                     0.282   34        0             False
# 376                     0.299   22        0             False
# 288                     0.340   26        0             False
# 416                     1.095   22        0             False
# 590                     0.925   45        1             False
# 630                     0.732   34        1             False

# %% [markdown]
# ## II. Data Transformation

# %% [markdown]
# ### 1. Removing Duplicates

# %%
data = pd.DataFrame({'k1': ['one', 'two'] * 3 + ['two'],
                     'k2': [1, 1, 2, 3, 3, 4, 4]})
data
# Out:
#     k1  k2
# 0  one   1
# 1  two   1
# 2  one   2
# 3  two   3
# 4  one   3
# 5  two   4
# 6  two   4

# %%
# Identify duplicated rows
data.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# dtype: bool

# %%
# Drop duplicated rows
data.drop_duplicates()
# Out:
#     k1  k2
# 0  one   1
# 1  two   1
# 2  one   2
# 3  two   3
# 4  one   3
# 5  two   4

# %%
# Drop duplicated values from column k1
data.drop_duplicates(['k1'])
# Out:
#     k1  k2
# 0  one   1
# 1  two   1

# %% [markdown]
# ## 2. Transforming Data Using a Function or Mapping

# %%
data = pd.DataFrame({'food': ['bacon', 'pulled pork', 'bacon',
                              'Pastrami', 'corned beef', 'Bacon',
                              'pastrami', 'honey ham', 'nova lox'],
                     'ounces': [4, 3, 12, 6, 7.5, 8, 3, 5, 6]})
data
# Out:
#           food  ounces
# 0        bacon     4.0
# 1  pulled pork     3.0
# 2        bacon    12.0
# 3     Pastrami     6.0
# 4  corned beef     7.5
# 5        Bacon     8.0
# 6     pastrami     3.0
# 7    honey ham     5.0
# 8     nova lox     6.0

# %%
# Suppose that we want to map the meat type to the kind of animal:
meat_to_animal = {
  'bacon': 'pig',
  'pulled pork': 'pig',
  'pastrami': 'cow',
  'corned beef': 'cow',
  'honey ham': 'pig',
  'nova lox': 'salmon'
}

# %%
# To make matching simpler, change strings to lowercase first
lowercased = data['food'].str.lower()
lowercased
data['animal'] = lowercased.map(meat_to_animal)
data
# Out:
#           food  ounces  animal
# 0        bacon     4.0     pig
# 1  pulled pork     3.0     pig
# 2        bacon    12.0     pig
# 3     Pastrami     6.0     cow
# 4  corned beef     7.5     cow
# 5        Bacon     8.0     pig
# 6     pastrami     3.0     cow
# 7    honey ham     5.0     pig
# 8     nova lox     6.0  salmon

# %%
# We can also pass a function
data['food'].map(lambda x: meat_to_animal[x.lower()])
# Out:
# 0       pig
# 1       pig
# 2       pig
# 3       cow
# 4       cow
# 5       pig
# 6       cow
# 7       pig
# 8    salmon
# Name: food, dtype: object
